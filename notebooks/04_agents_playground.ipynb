# %% [markdown]
# # 04 — Agents Playground
#
# Construa e execute agentes ReAct interativamente.

# %%
import sys; sys.path.insert(0, '..')

# %% [markdown]
# ## 1. Tools Individuais

# %%
from modules.agents.tools.calculator import calculator
from modules.agents.tools.web_search import web_search
print(calculator('2 ** 10'))
print(calculator('(1234 * 5678) / 3'))
# Out:
# 1024
# 2335550.6666666665

# %%
# Busca web (requer conexão)
result = web_search('RAG retrieval augmented generation 2024', max_results=3)
print(result[:500])
# Out:
# [1] A Comprehensive Survey of Retrieval-Augmented Generation (RAG ...
#     This paper presents a comprehensive study of Retrieval-Augmented Generation (RAG), tracing its evolution from foundational concepts to the current state of the art. RAG combines retrieval mechanisms with generative language models to enhance the accuracy of outputs, addressing key limitations of LLM
#     URL: https://arxiv.org/abs/2410.12837
# [2] Retrieval-Augmented Generation for AI-Generated Content: A Survey
#     Retrieval

# %% [markdown]
# ## 2. Simple Agent (single tool call)

# %%
from modules.agents.simple_agent import SimpleAgent
agent = SimpleAgent()
print(agent.run('Quanto é 15% de 2450?'))
# Out:
# [01:00:51] INFO     Chamando tool: calculator({"expression": "2450 * 15 / 100"})                 ]8;id=12664762;file://C:\Desenvolvimento\IA\Aprendizado\ProjetoInicial\notebooks\..\modules\agents\simple_agent.py\simple_agent.py]8;;\:]8;id=12664763;file://C:\Desenvolvimento\IA\Aprendizado\ProjetoInicial\notebooks\..\modules\agents\simple_agent.py#49\49]8;;\
# **15% de 2.450 é igual a 367,5** ✅
#
# > **Como foi calculado:**
# > 2.450 × 15 ÷ 100 = **367,5**
#
# Precisa de mais algum cálculo? 😊

# %% [markdown]
# ## 3. ReAct Agent (loop completo)

# %%
from modules.agents.react_agent import ReActAgent
react = ReActAgent(max_steps=6)
query = 'Qual é a raiz quadrada de 1764? E 20% desse valor?'
result = react.run(query)
print('Resultado:', result)
# Out:
# [01:00:54] INFO     [ReAct step 1/6]                                                              ]8;id=12664770;file://C:\Desenvolvimento\IA\Aprendizado\ProjetoInicial\notebooks\..\modules\agents\react_agent.py\react_agent.py]8;;\:]8;id=12664771;file://C:\Desenvolvimento\IA\Aprendizado\ProjetoInicial\notebooks\..\modules\agents\react_agent.py#73\73]8;;\
# Resultado: Aqui estão os resultados:
#
# - 🔢 **Raiz quadrada de 1764** = **42**
# - 📊 **20% de 42** = **8,4**
#
# > **Resumo:** √1764 = 42, e 20% desse valor é **8,4**.

# %% [markdown]
# ## Exercícios
#
# 1. Adicione um tool `rag_search(question)` que usa o pipeline RAG do módulo 02
# 2. Implemente `python_executor` e peça ao agente para escrever e rodar um script
# 3. Teste o multi_agent.py com uma tarefa de pesquisa complexa
